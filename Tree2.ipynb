# %% [markdown]
# <span style='font-size:20pt'> 이진탐색 트리 삭제 코드 구현. </span>

# %% [markdown]
# <b> 코드로 구현 작전</b>
#
# + 삭제할 Node의 오른쪽 자식 중, 가장 작은 값을 삭제할 Node의 Parent Node가 가리키게 할 경우
#
# 1. 삭제할 Node의 오른쪽 자식 선택
# 2. 오른쪽 자식의 가장 왼쪽에 있는 Node를 선택
# 3. 해당 Node를 삭제할 Node의 Parent Node의 왼쪽 branch가 가리키게 함
# 4. 해당 Node의 왼쪽 Branch가 삭제할 Node의 왼쪽 child Node를 가리키게 함
# 5. 해당 Node의 오른쪽 branch가 삭제할 Node의 오른쪽 Child Node를 가리키게 함
# 6. 만약 해당 Node가 오른쪽 Child Node를 가지고 있었을 경우에는, 해당 Node의 본래 Parent Node의 왼쪽 Branch 가 해당 오른쪽 ChildNode를 가리키게 함.

# %%
class Node:
    #노드를 넣을때부터 브랜치를 가지는 경우는 없기에 초기 좌 우 자식 노드는 None
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None
        
class NodeMgmt:
    def __init__(self, head):
        self.head = head
    
    def insert(self, value):
        self.current_node = self.head #시작 노드 즉 맨 위 노드부터 탐색 시작
        #순회하는 코드
        while True:
            #넣으려는 데이터가 중앙(부모)노드보다 작다면, 좌측으로 보낸다.
            if value < self.current_node.value: #내가 넣으려는 값이 현재 노드의 값보다 작으면
                #현재 노드의 왼쪽 자식 노드가 존재하는지를 먼저 확인, 왜냐하면 있으면 그 노드와 또 비교해서 좌우측을 고민해야되니까.
                if self.current_node.left != None: 
                    self.current_node = self.current_node.left #비교 대상을 바꿈.
                else:
                    self.current_node.left = Node(value) #브랜치가 없다면 새로 그냥 만들어서 이어줌 
                    break #while true를 빠져나오게끔 해줌.
            else:#이번엔 오른쪽으로 갈 경우
                if self.current_node.right != None:
                    self.current_node = self.current_node.right
                else:
                    self.current_node.right = Node(value)
                    break
                    
                    
    def search(self, value):
        self.current_node = self.head #시작은 최상위 노드부터 탐색
        while self.current_node: #self.current_node가 None이 되면 종료
            if self.current_node.value == value: #현재 노드의 값이 원하는 값이면
                return True
            elif value < self.current_node.value: #만약 내가 찾는 값이 현재 노드의 값보다 작으면 다음 탐색은 왼쪽으로
                self.current_node = self.current_node.left
            else:#아니면 오른쪽으로
                self.current_node = self.current_node.right
                
        return False #while문을 안탄다는건 찾고자 하는 값이 없다는 뜻

# %%
def delete(self, value):
    #삭제할 node가 있는지 탐색
    searched = False #이 트리에 없다. true면 있다.
    
    #current_node는 삭제할 노드, parent node는 삭제할 노드의 위에 부모 노드
    #삭제할 노드 찾는 코드
    self.current_node = self.head
    self.parent = self.head
    while self.current_node:
        if self.current_node.value == value:
            searched = True
            break
        elif value < self.current_node.value:
            self.parent = self.current_node
            self.current_node = self.current_node.left
        else:
            self.parent = self.current_node
            self.current_node = self.current_node.right
    #삭제할 노드 찾는 코드 끝
    
    #self.current_node가 none인 경우니까.. 존재하지않다는 뜻
    if searched == False:
        return False
    
    ### 이후부터는 Case분리해서 아래에 작성

# %% [markdown]
# # 삭제할 Node가 Leaf Node인 경우

# %%
#self.current_node : 삭제할 노드 
    if self.current_node.left == None and self.current_node.right == None: #leaf node이면
        
        #삭제하고 싶은 value가 부모값보다 작다면 왼쪽 자식 노드를 삭제해야되므로..
        #그냥 self.current_node = None이렇게 하면 안되는건가? branch도 지워야대서?
        # self.parent.left = None => 이건 연결 고리 를 끊는 행위, 노드는 남아있음. 아예 노드를 없애려면 del 쓰는것임!!!
        if value < self.parent.value:
            self.parent.left = None
        else:
            self.parent.right = None
        
        #그냥 이렇게 써도되는듯
        #메모리 디로딩인듯
        del self.current_node

# %% [markdown]
# ## 삭제할 노드가 Child Node를 한 개 가지고 있을 경우

# %% [markdown]
# ### 먼저 한 쪽 방향으로만 child node를 가지는 경우

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-02-18%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%201.43.40.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-02-18%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%201.43.40.png)

# %%
#왼쪽에만 child node 보유
if self.current_node.left != None and self.current_node.right == None:
    if value < self.parent.value: #5를 삭제할경우
        #parent와 맨 왼쪽의 주소를 연결
        self.parent.left = self.current_node.left
    else: #15를 삭제할 경우
        self.parent.right = self.current_node.left

#우측에만 child node 보유
elif self.current_node.left == None and self.current_node.right != None:
    if value < self.parent.value:
        self.parent.left = self.current_node.right
    else:
        self.parent.right = self.current_node.right
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1bacb54561d4> in <module>
#       1 #왼쪽에만 child node 보유
# ----> 2 if self.current_node.left != None and self.current_node.right == None:
#       3     if value < self.parent.value: #5를 삭제할경우
#       4         #parent와 맨 왼쪽의 주소를 연결
#       5         self.parent.left = self.current_node.left
#
# NameError: name 'self' is not defined

# %% [markdown]
# # 삭제할 노드가 Child Node를 두 개 가지고 있을 경우

# %% [markdown]
# 전략
#
# 1. 삭제할 Node의 오른쪽 자식 중 가장 작은 값을 삭제할 Node의 parent Node가 가리키도록 한다.
#
# 2. 삭제할 Node의 왼쪽 자식 중 가장 큰 값을 삭제할 Node의 parent Node가 가리키도록 한다.
#
# 전략 1을 사용 한다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 삭제할 Node가 Parent의 왼쪽에 있을 경우

# %%
#Case 3-1-1, 3-1-2를 작성
    #삭제할 노드가 child node를 양 쪽 다 가지고 있다는 것을 확인(current node 아래에 두 개가 있다는 것을 확인 )
    if self.current_node.left != None and self.current_node.right != None:
        #case 3-1 : 삭제할 노드가 왼쪽에 있을 경우
        if value < self.parent.value:
            #오른쪽을 순회해야 하므로
            self.change_node = self.current_node.right #change node : 가장 왼쪽아래 노드 -> 삭제할 노드 자리에 올릴것
            self.change_node_parent = self.current_node.right #초기에는 둘이 같은 노드. 이후 순회하면서 밀어냄
            while self.change_node.left != None: #끝 left 를 찾는 과정
                self.change_node_parent = self.change_node
                self.change_node = self.change_node.left
            
            #while이 끝나면 change_node는 가장 작은 노드가 되어있는 상태
            #Case 3-1-2 구현
            if self.change_node.right != None: #case 3-1-2 구분
                #right가 있으면
                self.change_node_parent.left = self.change_node.right
            else:
                self.change_node_parent.left = None #change_node_parent와 change_node의 고리를 none으로 만든다.
            
            
            #이제 삭제할 노드 자리를 위에서 찾은 우측 브랜치 중 작은 값 change_node로 대체해준다.
            self.parent.left = self.change_node
            #대체한 노드의 좌 우 재배열
            self.change_node.right = self.current_node.right
            self.change_node.left = self.current_node.left

# %% [markdown]
# ## 삭제할 Node가 Parent 의 오른쪽에 있을 경우

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#위에서 이미 삭제할 노드 밑에 양쪽이 다 있다는 것을 명시했으므로
        else:
            self.change_node = self.current_node.right
            self.change_node_parent = self.current_node.right
            while self.change_node.left != None:
                self.change_node_parent = self.change_node
                self.change_node = self.change_node.left
            #while문 종료시 change_node가 오른쪽 브랜치 중 가장 왼쪽 노드를 가지게 됨.
            if self.change_node.right != None:
                self.change_node_parent.left = self.change_node.right
            else:
                self.change_node_parent.left = None
            
            #삭제할 노드를 change_node로 대체
            self.parent.right = self.change_node
            #self.change_node 아래 재배열
            self.change_node.left = self.current_node.left
            self.change_node.right = self.current_node.right
